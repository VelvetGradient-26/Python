# %%
import statistics as stats
import random

# %%
random.seed(42)

lst = [random.randint(1,100) for _ in range(25)]
print(lst)
# Out:
# [82, 15, 4, 95, 36, 32, 29, 18, 95, 14, 87, 95, 70, 12, 76, 55, 5, 4, 12, 28, 30, 65, 78, 4, 72]

# %%
# use the stats module for mean
stats.mean(lst)
# Out:
# 44.52

# %%
# Median
stats.median(lst)
# Out:
# 32

# %%
# Mode
stats.mode(lst)
# Out:
# 4
